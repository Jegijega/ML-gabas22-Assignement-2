# %%
# !pip install -q mlflow

# %%
import os
import mlflow
from kaggle_secrets import UserSecretsClient

DATA_DIR = "/kaggle/input/competitions/ieee-fraud-detection"

secrets = UserSecretsClient()
os.environ["MLFLOW_TRACKING_USERNAME"] = "gabas22"
os.environ["MLFLOW_TRACKING_PASSWORD"] = secrets.get_secret("DAGSHUB_TOKEN")

mlflow.set_tracking_uri("https://dagshub.com/gabas22/ML-gabas22-Assignement-2.mlflow")
mlflow.set_experiment("DecisionTree_Training")
# Out:
# <Experiment: artifact_location='mlflow-artifacts:/15c93caa763146858ed61cb1d7d0df02', creation_time=1777819372331, experiment_id='1', last_update_time=1777819372331, lifecycle_stage='active', name='DecisionTree_Training', tags={}, trace_location=None, workspace='default'>

# %%
import pandas as pd

train_t = pd.read_csv(f"{DATA_DIR}/train_transaction.csv")
train_i = pd.read_csv(f"{DATA_DIR}/train_identity.csv")
test_t  = pd.read_csv(f"{DATA_DIR}/test_transaction.csv")
test_i  = pd.read_csv(f"{DATA_DIR}/test_identity.csv")

print("train_transaction:", train_t.shape)
print("train_identity:   ", train_i.shape)
print("test_transaction: ", test_t.shape)
print("test_identity:    ", test_i.shape)
# Out:
# train_transaction: (590540, 394)
# train_identity:    (144233, 41)
# test_transaction:  (506691, 393)
# test_identity:     (141907, 41)

# %%
train = train_t.merge(train_i, how="left", on="TransactionID")
test  = test_t.merge(test_i,  how="left", on="TransactionID")

print("train merged:", train.shape)
print("test merged: ", test.shape)
print()
print("Fraud distribution:")
print(train["isFraud"].value_counts())
print("Fraud rate:", train["isFraud"].mean())
# Out:
# train merged: (590540, 434)
# test merged:  (506691, 433)
#
# Fraud distribution:
# isFraud
# 0    569877
# 1     20663
# Name: count, dtype: int64
# Fraud rate: 0.03499000914417313

# %% [markdown]
# Cleaning

# %%
nan_pct = train.isna().mean().sort_values(ascending=False)
print(nan_pct.head(20))
print()
print("columns with >90% missing:", (nan_pct > 0.9).sum())
print("columns with >50% missing:", (nan_pct > 0.5).sum())
# Out:
# id_24    0.991962
# id_25    0.991310
# id_07    0.991271
# id_08    0.991271
# id_21    0.991264
# id_26    0.991257
# id_27    0.991247
# id_23    0.991247
# id_22    0.991247
# dist2    0.936284
# D7       0.934099
# id_18    0.923607
# D13      0.895093
# D14      0.894695
# D12      0.890410
# id_04    0.887689
# id_03    0.887689
# D6       0.876068
# id_33    0.875895
# id_09    0.873123
# dtype: float64
#
# columns with >90% missing: 12
# columns with >50% missing: 214

# %%
test = test.rename(columns={c: c.replace("-", "_") for c in test.columns})
print("test cols renamed")
# Out:
# test cols renamed

# %%
threshold = 0.7
drop_cols = nan_pct[nan_pct > threshold].index.tolist()
with mlflow.start_run(run_name="DecisionTree_Cleaning_t07"):
    mlflow.log_param("nan_threshold", threshold)
    mlflow.log_param("dropped_cols", len(drop_cols))
    train_c = train.drop(columns=drop_cols)
    test_c  = test.drop(columns=drop_cols)
    mlflow.log_metric("cols_after", train_c.shape[1])
print("dropped:", len(drop_cols))
print("shape after:", train_c.shape)
# Out:
# 🏃 View run DecisionTree_Cleaning_t07 at: https://dagshub.com/gabas22/ML-gabas22-Assignement-2.mlflow/#/experiments/1/runs/188e7d0135de4059a2a70a94a6f2f724
# 🧪 View experiment at: https://dagshub.com/gabas22/ML-gabas22-Assignement-2.mlflow/#/experiments/1
# dropped: 208
# shape after: (590540, 226)

# %%
threshold = 0.8
drop_cols = nan_pct[nan_pct > threshold].index.tolist()
with mlflow.start_run(run_name="DecisionTree_Cleaning_t08"):
    mlflow.log_param("nan_threshold", threshold)
    mlflow.log_param("dropped_cols", len(drop_cols))
    train_c = train.drop(columns=drop_cols)
    test_c  = test.drop(columns=drop_cols)
    mlflow.log_metric("cols_after", train_c.shape[1])
print("dropped:", len(drop_cols))
print("shape after:", train_c.shape)
# Out:
# 🏃 View run DecisionTree_Cleaning_t08 at: https://dagshub.com/gabas22/ML-gabas22-Assignement-2.mlflow/#/experiments/1/runs/4755c56ace784e70beed4247a3c86f14
# 🧪 View experiment at: https://dagshub.com/gabas22/ML-gabas22-Assignement-2.mlflow/#/experiments/1
# dropped: 74
# shape after: (590540, 360)

# %%
threshold = 0.9
drop_cols = nan_pct[nan_pct > threshold].index.tolist()
with mlflow.start_run(run_name="DecisionTree_Cleaning_t09"):
    mlflow.log_param("nan_threshold", threshold)
    mlflow.log_param("dropped_cols", len(drop_cols))
    train_c = train.drop(columns=drop_cols)
    test_c = test.drop(columns=drop_cols)
    mlflow.log_metric("cols_after", train_c.shape[1])
print("dropped:", len(drop_cols))
print("shape after:", train_c.shape)
# Out:
# 🏃 View run DecisionTree_Cleaning_t09 at: https://dagshub.com/gabas22/ML-gabas22-Assignement-2.mlflow/#/experiments/1/runs/7b443db223fd4f029434212760d47b20
# 🧪 View experiment at: https://dagshub.com/gabas22/ML-gabas22-Assignement-2.mlflow/#/experiments/1
# dropped: 12
# shape after: (590540, 422)

# %% [markdown]
# Feature Engineering

# %%
train_c["TransactionAmt"].describe()
# Out:
# count    590540.000000
# mean        135.027176
# std         239.162522
# min           0.251000
# 25%          43.321000
# 50%          68.769000
# 75%         125.000000
# max       31937.391000
# Name: TransactionAmt, dtype: float64

# %%
import numpy as np
train_c["hour"] = (train_c["TransactionDT"] // 3600) % 24
test_c["hour"] = (test_c["TransactionDT"] // 3600) % 24
train_c["day"] = (train_c["TransactionDT"] // (3600*24)) % 7
test_c["day"] = (test_c["TransactionDT"] // (3600*24)) % 7
print(train_c[["TransactionAmt", "hour", "day"]].head())
# Out:
#    TransactionAmt  hour  day
# 0            68.5     0    1
# 1            29.0     0    1
# 2            59.0     0    1
# 3            50.0     0    1
# 4            50.0     0    1

# %%
with mlflow.start_run(run_name="DecisionTree_Feature_Engineering"):
    mlflow.log_param("time_features", "hour,day")
    mlflow.log_metric("new_features", 2)
    mlflow.log_metric("cols_total", train_c.shape[1])
print("cols total:", train_c.shape[1])
# Out:
# 🏃 View run DecisionTree_Feature_Engineering at: https://dagshub.com/gabas22/ML-gabas22-Assignement-2.mlflow/#/experiments/1/runs/62b71349c96e4619b183fde367e5a597
# 🧪 View experiment at: https://dagshub.com/gabas22/ML-gabas22-Assignement-2.mlflow/#/experiments/1
# cols total: 424

# %% [markdown]
# Feature Selection

# %%
threshold_corr = 0.95
num_cols = train_c.select_dtypes(include=[np.number]).columns.drop(["isFraud", "TransactionID"])
corr = train_c[num_cols].sample(100000, random_state=42).corr().abs()
upper = corr.where(np.triu(np.ones(corr.shape), k=1).astype(bool))
drop_corr = [c for c in upper.columns if (upper[c] > threshold_corr).any()]
with mlflow.start_run(run_name="DecisionTree_Feature_Selection"):
    mlflow.log_param("corr_threshold", threshold_corr)
    mlflow.log_param("dropped_corr", len(drop_corr))
    train_fs = train_c.drop(columns=drop_corr)
    test_fs = test_c.drop(columns=drop_corr)
    mlflow.log_metric("cols_after_fs", train_fs.shape[1])
print("dropped:", len(drop_corr))
print("shape after FS:", train_fs.shape)
# Out:
# 🏃 View run DecisionTree_Feature_Selection at: https://dagshub.com/gabas22/ML-gabas22-Assignement-2.mlflow/#/experiments/1/runs/97ca72636b2946b1a3e74470e73b986a
# 🧪 View experiment at: https://dagshub.com/gabas22/ML-gabas22-Assignement-2.mlflow/#/experiments/1
# dropped: 139
# shape after FS: (590540, 285)

# %% [markdown]
# Training

# %%
from sklearn.base import BaseEstimator, TransformerMixin
class FraudPrep(BaseEstimator, TransformerMixin):
    def __init__(self, drop_cols):
        self.drop_cols = drop_cols
    def fit(self, X, y=None):
        self.cat_maps_ = {}
        self.medians_ = {}
        Xt = self._prep(X.drop(columns=[c for c in self.drop_cols if c in X.columns]))
        for c in Xt.columns:
            if Xt[c].dtype == "object":
                cats = Xt[c].fillna("missing").astype(str).unique().tolist()
                self.cat_maps_[c] = {v: i for i, v in enumerate(cats)}
            else:
                self.medians_[c] = Xt[c].median()
        return self
    def transform(self, X):
        Xt = self._prep(X.drop(columns=[c for c in self.drop_cols if c in X.columns]))
        for c, m in self.cat_maps_.items():
            if c in Xt.columns:
                Xt[c] = Xt[c].fillna("missing").astype(str).map(m).fillna(-1).astype(int)
        for c, med in self.medians_.items():
            if c in Xt.columns:
                Xt[c] = Xt[c].fillna(med)
        return Xt.values
    def _prep(self, X):
        X = X.copy()
        X["hour"] = (X["TransactionDT"] // 3600) % 24
        X["day"] = (X["TransactionDT"] // (3600*24)) % 7
        return X

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import StratifiedKFold, cross_val_score
sample = train_fs.sample(200000, random_state=42)
y = sample["isFraud"]
X = sample.drop(columns=["isFraud", "TransactionID"]).copy()
for c in X.select_dtypes(include=["object"]).columns:
    X[c] = X[c].fillna("missing").astype("category").cat.codes
X = X.fillna(-999)
cv = StratifiedKFold(n_splits=3, shuffle=True, random_state=42)
for d in [3, 10, None]:
    for cw in [None, "balanced"]:
        m = DecisionTreeClassifier(max_depth=d, class_weight=cw, random_state=42)
        scores = cross_val_score(m, X, y, cv=cv, scoring="roc_auc", n_jobs=-1)
        cw_label = "none" if cw is None else "balanced"
        with mlflow.start_run(run_name=f"DecisionTree_Training_d{d}_{cw_label}"):
            mlflow.log_param("max_depth", str(d))
            mlflow.log_param("class_weight", cw_label)
            mlflow.log_param("cv_folds", 3)
            mlflow.log_param("sample_size", len(X))
            mlflow.log_metric("cv_auc_mean", scores.mean())
            mlflow.log_metric("cv_auc_std", scores.std())
        print(f"d={d}, cw={cw_label}: AUC={scores.mean():.4f} +/- {scores.std():.4f}")
# Out:
# 🏃 View run DecisionTree_Training_d3_none at: https://dagshub.com/gabas22/ML-gabas22-Assignement-2.mlflow/#/experiments/1/runs/fb97874c99374012afdf8eb1b637851d
# 🧪 View experiment at: https://dagshub.com/gabas22/ML-gabas22-Assignement-2.mlflow/#/experiments/1
# d=3, cw=none: AUC=0.6362 +/- 0.0072
# 🏃 View run DecisionTree_Training_d3_balanced at: https://dagshub.com/gabas22/ML-gabas22-Assignement-2.mlflow/#/experiments/1/runs/71370ec81bd340dc89d8b7b26c5009f2
# 🧪 View experiment at: https://dagshub.com/gabas22/ML-gabas22-Assignement-2.mlflow/#/experiments/1
# d=3, cw=balanced: AUC=0.7694 +/- 0.0041
# 🏃 View run DecisionTree_Training_d10_none at: https://dagshub.com/gabas22/ML-gabas22-Assignement-2.mlflow/#/experiments/1/runs/a7deaa2e576e44b5b33346844090e108
# 🧪 View experiment at: https://dagshub.com/gabas22/ML-gabas22-Assignement-2.mlflow/#/experiments/1
# d=10, cw=none: AUC=0.7699 +/- 0.0065
# 🏃 View run DecisionTree_Training_d10_balanced at: https://dagshub.com/gabas22/ML-gabas22-Assignement-2.mlflow/#/experiments/1/runs/1d9b99dfc1ac4a43964e02bbec64a6a1
# 🧪 View experiment at: https://dagshub.com/gabas22/ML-gabas22-Assignement-2.mlflow/#/experiments/1
# d=10, cw=balanced: AUC=0.8321 +/- 0.0048
# 🏃 View run DecisionTree_Training_dNone_none at: https://dagshub.com/gabas22/ML-gabas22-Assignement-2.mlflow/#/experiments/1/runs/0749623892164fb48932c4c37bd98903
# 🧪 View experiment at: https://dagshub.com/gabas22/ML-gabas22-Assignement-2.mlflow/#/experiments/1
# d=None, cw=none: AUC=0.7288 +/- 0.0023
# 🏃 View run DecisionTree_Training_dNone_balanced at: https://dagshub.com/gabas22/ML-gabas22-Assignement-2.mlflow/#/experiments/1/runs/f004acd3620044a5a0a8d4490fa2ecae
# 🧪 View experiment at: https://dagshub.com/gabas22/ML-gabas22-Assignement-2.mlflow/#/experiments/1
# d=None, cw=balanced: AUC=0.7125 +/- 0.0028

# %%
from sklearn.pipeline import Pipeline
nan_pct = train.isna().mean()
nan_drop = nan_pct[nan_pct > 0.9].index.tolist()
all_drop = list(set(nan_drop) | set(drop_corr) | {"TransactionID"})
y_full = train["isFraud"]
X_full = train.drop(columns=["isFraud"])
final_pipe = Pipeline([("prep", FraudPrep(drop_cols=all_drop)), ("dt", DecisionTreeClassifier(max_depth=10, class_weight="balanced", random_state=42))])
final_pipe.fit(X_full, y_full)
print("fitted")
# Out:
# fitted

# %%
import joblib
joblib.dump(final_pipe, "dt_pipeline.pkl")
test_preds = final_pipe.predict_proba(test)[:, 1]
print("preds shape:", test_preds.shape, "first:", test_preds[:3])
with mlflow.start_run(run_name="DecisionTree_FinalPipeline"):
    mlflow.log_param("max_depth", 10)
    mlflow.log_param("class_weight", "balanced")
    mlflow.log_metric("cv_auc", 0.8321)
    mlflow.log_artifact("dt_pipeline.pkl")
print("saved")
# Out:
# preds shape: (506691,) first: [0.17262621 0.23432611 0.23432611]
# 🏃 View run DecisionTree_FinalPipeline at: https://dagshub.com/gabas22/ML-gabas22-Assignement-2.mlflow/#/experiments/1/runs/e659d54f2978408c9e71a341cb88c166
# 🧪 View experiment at: https://dagshub.com/gabas22/ML-gabas22-Assignement-2.mlflow/#/experiments/1
# saved
